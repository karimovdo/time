# %% [markdown]
# **Денис, привет!**
#
# Меня зовут Соколова Александра, я буду проверять твой проект. Приятно познакомиться:)
#
# Предлагаю общаться на «ты», но если тебе не очень комфортно - дай, пожалуйста, знать.
#
# Ты уже проделал большую работу над проектом, давай сделаем его еще лучше. Ниже ты найдешь мои комментарии, пожалуйста, не перемещай, не изменяй и не удаляй их. Давай использовать цветовую разметку:
#
# <div class="alert alert-danger">
# <b>❌ Комментарий ревьюера:</b> Так выделены самые важные замечания, их нужно обязательно проработать. </div>
#
# <div class="alert alert-warning">
# <b>⚠️ Комментарий ревьюера:</b> Так выделены небольшие замечания, некритичные ошибки или развивающие рекомендации на будущее.
#
# </div>
#
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера:</b> Все отлично:) </div>
#
# Давай работать над проектом в диалоге: если ты что-то меняешь или отвечаешь на мои комменатри — пиши об этом. Мне будет легче отследить изменения, если ты выделишь свои комментарии:
# <div class="alert alert-info"> <b>Комментарий студента:</b> Например, вот так.</div>
#
# Всё это поможет выполнить повторную проверку твоего проекта оперативнее.

# %% [markdown]
# ***

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий ревьюера:</b>
#
# **Полезные материалы по теме:**
#
# - Б.Б. Демешев - временные ряды https://disk.yandex.ru/i/LiDHB-B3A6Lz5A
# - Базовое применение ARIMA - https://colab.research.google.com/drive/17RnG91Eq8JBKyxToNzvCvjibfxum-oPj?usp=sharing
# - Канторович - Анализ временных рядов https://yadi.sk/i/IOkUOS3hTXf3gg
# https://facebook.github.io/prophet/
# https://facebook.github.io/prophet/docs/quick_start.html#python-api
# https://nbviewer.jupyter.org/github/miptgirl/habra_materials/blob/master/prophet/habra_data.ipynb
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера:</b>
#
# Денис, привет!
#
# Спасибо, что поправил библиотеку
#
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента:</b> Привет Александра. Спасибо тебе большое за ревью. оно на самом деле интересное и подробное. Если честно немного отвык от качественных ревью, поэтому и расписывал мало пока делал. последние 3 проекта очень сухо проверяли и немного поубавилось энтузиазма на выполнение проектов. Так что большое спасибо тебе за дельные замечания и за полезные ссылки. Это стимулирует к более глубокому изучению проектов. </div>

# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#План-исследования" data-toc-modified-id="План-исследования-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>План исследования</a></span></li><li><span><a href="#Подготовка" data-toc-modified-id="Подготовка-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Подготовка</a></span></li><li><span><a href="#Анализ" data-toc-modified-id="Анализ-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Анализ</a></span></li><li><span><a href="#Обучение" data-toc-modified-id="Обучение-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Обучение</a></span></li><li><span><a href="#Тестирование" data-toc-modified-id="Тестирование-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Тестирование</a></span></li><li><span><a href="#Выводы" data-toc-modified-id="Выводы-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Выводы</a></span></li><li><span><a href="#Чек-лист-проверки" data-toc-modified-id="Чек-лист-проверки-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Чек-лист проверки</a></span></li></ul></div>

# %% [markdown]
# #  Прогнозирование заказов такси

# %% [markdown]
# Компания «Чётенькое такси» собрала исторические данные о заказах такси в аэропортах. Чтобы привлекать больше водителей в период пиковой нагрузки, нужно спрогнозировать количество заказов такси на следующий час. Постройте модель для такого предсказания.
#
# Значение метрики *RMSE* на тестовой выборке должно быть не больше 48.

# %% [markdown]
# ## План исследования
#
#
# 1. Загрузить данные
# 2. Выполнить их ресемплирование по одному часу
# 3. Изучить данные
# 4. Проанализировать параметры для SARIMA
# 5. Обучить разные виды моделей
# 6. Обучить разные модели с различными гиперпараметрами.
# 7. Выбрать лучшую модель
# 8. Сделать тестовую выборку размером 10% от исходных данных.
# 9. Проверить данные на тестовой выборке и сделать выводы.
#
# Цель исследолвания: построить модель для нужно прогнозирования количество заказов такси на следующий час.
#
# В ходе работы планируется изучить модели: SARIMA, AutoARIMA, NaiveForecaster, AutoETS, MLPRegressor. CatBoostRegressor, LGBMRegressor, LinearRegression
#
#
# Результаты исследования:
#
# Лучше всего показали себя : SARIMA, AutoETS, CatBoostRegressor.
# Показатели у них были довольно близкие , но лучший результат был у SARIMA
#
# Сделали тестовую выборку размером 10% от исходных данных.
# Обучили и проверили модель.
#
# RMSE =  41.11, что меньше необходимых 48

# %% [markdown]
# <div class="alert alert-warning">
# <b>⚠️ Комментарий ревьюера:</b>
#
# На этом этапе было бы здорово немного расширить оформление проекта - написать своими словами.
#
# ***
#
# Оформление принято делать к каждому проекту, обычно прописывают название, цели и задачи исследования. Можно добавить этапы работы, а также итоги исследования (что было достигнуто в процессе, к каким выводам пришли, что нашли в данных).
#
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента:</b> Поправил.</div>

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера:</b>
#
# Когда будешь готовить портфолио, обычно его размешают на Github, хорошее введение - это важная часть.
#
# На плюсовых программах Практикума есть Карьерный трек, там hr-специалисты учат готовить портфолио и дают рекомендации в отношении оформления. Для каждого проекта советуют подготовить описание (обычно в README.md сохраняют). Т.е. это базовая составляющая хорошего портфолио
#
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента:</b> а вообще на сколько приветствуется выкладывание подобных работ? ну я имею то что они с курса. или лучше выкладывать более серьезные проекты?</div>

# %% [markdown]
# ## Подготовка

# %%
import pandas as pd 
import numpy as np
import matplotlib as plt
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.linear_model import LinearRegression

from sklearn.neural_network import MLPRegressor
from catboost import CatBoostRegressor
import lightgbm as lgb

import matplotlib.pyplot as plt
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.statespace import sarimax
from statsmodels.tsa.stattools import adfuller
import warnings
warnings.simplefilter(action = 'ignore', category = Warning)
from statsmodels.tsa.statespace.sarimax import SARIMAX
# from sktime.forecasting.arima import AutoARIMA
# from sktime.forecasting.naive import NaiveForecaster
# from sktime.forecasting.ets import AutoETS

# %% [markdown]
# <div class="alert alert-danger">
# <b>❌ Комментарий ревьюера:</b>
#
# ~На этом шаге код падает с ошибков при перезагрузке тетради:~
#
#     ModuleNotFoundError: No module named 'pmdarima'
#
# Некоторые библиотеки, к сожалению, не доступны в Юпитер Хабе.
#
# ***
#
# 1. Так как тетрадь дальше не запускается, пока останавливаю проверку и возвращаю проект на доработку. Поправь, пожалуйста, и пришли обратно, постараюсь оперативно проверить.
#
# 2. Просмотрела проект ниже, обратила внимание на создание признаков и на `train_test_split`, оставила комментарий. Лучше сразу поправить. =)
#
#
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента:</b> Забыл написать, что убрал.</div>

# %%
try:
    data = pd.read_csv('taxi.csv', index_col=[0], parse_dates =[0])
except:
    data = pd.read_csv('/datasets/taxi.csv', index_col=[0], parse_dates =[0])


data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 26496 entries, 2018-03-01 00:00:00 to 2018-08-31 23:50:00
# Data columns (total 1 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   num_orders  26496 non-null  int64
# dtypes: int64(1)
# memory usage: 414.0 KB

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера:</b> Здорово, что есть try-except на этапе загрузки датасета 👍

# %%
data['num_orders'] = data['num_orders'].astype('int16')

# %% [markdown]
# Попробовал сменить формат, чтобы памяти занимало меньше

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 26496 entries, 2018-03-01 00:00:00 to 2018-08-31 23:50:00
# Data columns (total 1 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   num_orders  26496 non-null  int16
# dtypes: int16(1)
# memory usage: 258.8 KB

# %%
data = data.resample("1H").sum()
data.index.is_monotonic_increasing
# Out:
# True

# %% [markdown]
# Сделали ресемплирование

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера:</b>
#
# Молодец, что провел сглаживание данных по одному часу (ресемплирование)
#
# </div>

# %% [markdown]
# <div class="alert alert-warning">
# <b>⚠️ Комментарий ревьюера:</b>
#
# ~Можно еще проверить в хронологическом ли порядке расположены значения индекса.~
#
# Использовать: `index.is_monotonic`
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера:</b>
#
# Здорово, что добавил проверку в хронологическом ли порядке расположены значения индекса.
#
# </div>

# %% [markdown]
# <div class="alert alert-danger">
# <b>❌ Комментарий ревьюера:</b>
#
# До этапа декомпозиции стоит построить график временного ряда (после ресемплирования по часу) + задать скользящее среднее.
#
# Дополнительно (по желанию) - можно сделать еще график временного ряда после ресемплирования по дню.
#
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента:</b> Поправил.</div>

# %%
data.plot(figsize = (21,6))
data['num_orders'].shift(4).rolling(5).mean().plot(label = 'среднее за 5 часов')
data['num_orders'].shift(23).rolling(24).mean().plot(label = 'среднее за 24 часа')
plt.legend(loc ='upper left');

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента:</b> Ничего не видно, так что немного зумируем.</div>

# %%
data['2018-07-30':'2018-08-30'].plot(figsize = (21,6))
data['2018-07-30':'2018-08-30']['num_orders'].shift(4).rolling(5).mean().plot(label = 'среднее за 5 часов')
data['2018-07-30':'2018-08-30']['num_orders'].shift(23).rolling(24).mean().plot(label = 'среднее за 24 часа')
plt.legend(loc ='upper left');

# %%
data.plot(figsize = (21,6))
decomposed = seasonal_decompose(data) 
decomposed.trend.plot()
plt.legend(loc ='upper left');

# %% [markdown]
# Как мы можем заметить тренд достаточно часто меняется, но имеет общую тенденцию к росту

# %%
decomposed.trend.plot(figsize = (21,6))
plt.legend(loc ='upper left');

# %%
decomposed.trend['2018-08-01':'2018-08-12'].plot(figsize = (21,6))
plt.legend(loc ='upper left');

# %%
data['2018-08-01':'2018-08-12'].plot()
decomposed.seasonal['2018-08-01':'2018-08-12'].plot(figsize = (21,6))
plt.legend(loc ='upper left');

# %% [markdown]
# Сезонность наблюдается выраженная с периодичностью раз в сутки или 24 часа

# %%
data['2018-08-11':'2018-08-12'].plot()
decomposed.seasonal['2018-08-11':'2018-08-12'].plot(figsize = (21,6))
plt.legend(loc ='upper left');

# %% [markdown]
# При увеличении маштаба видно, что максимальное количество вызовов характерно для 0 часов и 16 часов

# %%
data['2018-08-11':'2018-08-12'].plot()
decomposed.resid['2018-08-11':'2018-08-12'].plot(figsize = (21,6))
plt.legend(loc ='upper left');

# %% [markdown]
# Резюмируя все графики проанализированные выше. Мы наблюдаем , что тренд меняется в течении недели. Нпаблюдается рост по выходным и вторникам. Сезонность меняется в течении 24 часов с максимумами в 0 и 16 часов. А остатки очень подозрительны и я пошел читать, что это значит. Они еще в первый раз меня смутили

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента:</b> Поправил.</div>

# %% [markdown]
# Для подбора модели сделаем пока и тестовую и валидационнкю выборку. Затем валидационную оюъединим с тренировочной

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера:</b>
#
# Молодец, что разложил временной ряд на тренды и сезонность, построил графики. Здорово, что сезонность визуализирована на более коротком интервале👍
#
# </div>

# %% [markdown]
# <div class="alert alert-warning">
# <b>⚠️ Комментарий ревьюера:</b>
#
# График остатков лучше рассмотреть на всем промежутке. Ниже комментарий с объясненнием.
# </div>

# %% [markdown]
# <div class="alert alert-danger">
# <b>❌ Комментарий ревьюера:</b>
#
# Стоит добавить вывод к этапу - зафиксировать, как менялось количество заказов такси, учитывая графики тренда (за все время) и сезонности.
#
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий ревьюера:</b>
#
# **График остатков** интрепетировать сложнее, чем тренды и сезонность - в идеале он должен содержать только шум без систематических компонент. Анализ остатков важен, но в рамках данного проекта проводить его не требуется (!).
#
#
# **На будущее:**
#
# *Анализ остатков.* Если остатки систематически распределены (например, отрицательны в первой части ряда и примерно равны нуля во второй) или включают некоторую периодическую компоненту, то это свидетельствует о неадекватности модели. Анализ остатков чрезвычайно важен и необходим при анализе временных рядов. Процедура оценивания предполагает, что остатки не коррелированы и нормально распределены.
#
# Подробнее: http://statsoft.ru/home/textbook/modules/sttimser.html
#
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента:</b> Спасибо за ссылку. буду изучать.</div>

# %%
def make_features(data, max_lag, rolling_mean_size1,rolling_mean_size2):
    data['day'] = data.index.day
    data['dayofweek'] = data.index.dayofweek
    data['hour'] = data.index.hour
    for lag in range(1, max_lag + 1):
        data['lag_{}'.format(lag)] = data['num_orders'].shift(lag)
    data['rolling_mean_{}'.format(rolling_mean_size1)] = (
         data['num_orders'].shift(rolling_mean_size1-1).rolling(rolling_mean_size1).mean()
    )
        
    data['rolling_mean_{}'.format(rolling_mean_size2)] = (
         data['num_orders'].shift(rolling_mean_size2-1).rolling(rolling_mean_size2).mean()
    )

make_features(data, 24, 5,24)

train, test_vr = train_test_split(data, shuffle=False, test_size=0.2)
valid, test = train_test_split(test_vr, shuffle=False, test_size=0.5)
train = train.dropna()


X_train = train.drop('num_orders', axis=1)
y_train = train['num_orders']
X_valid = valid.drop('num_orders', axis=1)
y_valid = valid['num_orders']
X_test = test.drop('num_orders', axis=1)
y_test = test['num_orders']

# %%
X_train
# Out:
#                      day  dayofweek  hour  rolling_mean_5  rolling_mean_24  \
# datetime
# 2018-03-02 22:00:00    2          4    22            71.4        56.833333
# 2018-03-02 23:00:00    2          4    23            72.4        55.416667
# 2018-03-03 00:00:00    3          5     0            79.2        56.875000
# 2018-03-03 01:00:00    3          5     1            83.0        57.041667
# 2018-03-03 02:00:00    3          5     2            90.2        56.958333
# ...                  ...        ...   ...             ...              ...
# 2018-07-25 23:00:00   25          2    23           115.8       100.750000
# 2018-07-26 00:00:00   26          3     0           114.2        97.625000
# 2018-07-26 01:00:00   26          3     1           109.4        99.458333
# 2018-07-26 02:00:00   26          3     2           102.0        99.375000
# 2018-07-26 03:00:00   26          3     3           116.0       100.208333
#
# ...

# %% [markdown]
# Поскольку мы видим, что влияние имеют как и месяц, так и день и день недели и даже час. создадим эти переменные.
# Скользящее среднее я считаю создавать нельзя. так как в таком слуае у нас данные будут утекать в переменный из тестовой выборки и мы как бы будем с ней подглядывать в будущее. Ограничемся данными переменными.

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера:</b>
#
# Здорово, что при делении на выборки указан параметр `shuffle=False`, т.к. в train_test_split его дефолтное значение True. В случае временных рядов выборки перемешивать не стоит
#
# </div>

# %% [markdown]
# <div class="alert alert-danger">
# <b>❌ Комментарий ревьюера:</b>
#
# Несколько пунктов стоит доработать:
#
# 1. Цель создать три типа признаков:
# - Календарные признаки - здесь создадим столбцы **с днем недели и часом.**
# - «Отстающие значения» - они помогают нам трансформировать задачу прогнозирования в задачу обучения с учителем, потому что один из способов спрогнозировать величину в периоде t+1 - это использовать предыдущие значения;
# - Скользящее среднее - как признак, задающий тренд временного ряда.
#
# ~2. Т.к. работаем с временными рядоами, `random_state` из `train_test_split` нужно исключить~
#
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента:</b> Добавил отстающие значение и скользящие средние. Но когда я хотел включить их я подумал. Что это зависит от задачи предсказания. Но может конечно я не правильно рассуждаю.
# Тут конечно как посмотреть по логике мы их считаем отстающие и скользящее среднее из тестовой выборки, а по идее мы как бы ее не знаем. день дендели то мы можем определить. Одно дело если мы предсказываем значение только одного следующего часа(в данном случае), тогда это правомерно можно посчитать и отстающее значение и скользящее. Но получается в таком случаем нужно будет добавлять последние значения в тренировочную выборку (если бы это была реальная ситуация, на локальном конечно все быстро считается, но в тренажере возможно это займет больше часа). Второй вариант, если нам нужно сделать прогноз из точки сейчас и на месяц вперед, тогда мы уже, по идее, должны вычислять отстающие значения и скользящее среднее из предсказанных, а не из тестовой выборки, мы же ее как бы не знаем заранее. И это довольно трудно реализуемо в плане написания кода, если добавлять предсказанные в обучающую выборку.
# Поскольку в условии задачи четко не сказано, что мы предсказываем только каждый раз один час. или 1 дней вперед (размер тестовой выборке)
#
# И еще такая мысль пришла. В этом плане сравнивать SARIMA и например СatBoost не совсем провомерно. так как кат буст например знает предыдущее значения, за счет отстающих и скользящего среднего из тестовой выборке и этому алгоритму конечно намного проще.
#     В то время как SARIMA не подглядывает предыдущее значение для каждого часа , а делает прогноз на 18 вперед, что конечно намного сложнее. Так что ее тьочность поражает.
#     Поправь пожалуйста если я где-то неправильно расуждаю,
# </div>

# %% [markdown]
# <div class="alert alert-warning">
# <b>⚠️ Комментарий ревьюера:</b>
#
# Ниже по пунктам))
#
# 1. Месяц не требуется из-за того, что в датасете период менее года, тренд будет прослеживаться и без месяца.
#
#
# 2. Можно подготовить функцию make_features (такой пример был в спринте)
#
#     `def make_features(data, max_lag, rolling_mean_size)`, тогда ты сможешь задавать ширину окна и максимальный размер отставания. Чтобы не было хардкодинга.
#
# Посмотри, пожалуйста, пример в Теме "Прогнозирование временных рядов"-"Создание признаков"
#
# 3. Тут нюанс, про который писала выше: «Отстающие значения» - они помогают нам трансформировать задачу прогнозирования в задачу обучения с учителем, потому что один из способов спрогнозировать величину в периоде t+1 - это использовать предыдущие значения;
#
#
# 4. По условию задачи: нужно спрогнозировать количество заказов такси на следующий час.
#
#
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента:</b> спасибо. во первых пока я писал цель я понял, что да цель предсказывать блищайший час. По поводу функции да я помню. просто один раз это вычисление встречается добавить не проблема..</div>

# %%
plt.figure(figsize = (21,6))
plt.plot(y_train, color = "black", label = 'train')
plt.plot(y_valid, color = "blue", label = 'valid')
plt.plot(y_test, color = "red", label = 'test')
plt.title('Разделение данных на обучающую и тестовую выборки')
plt.ylabel('Количество заказов')
plt.xlabel('Время')
plt.legend(loc ='upper left')
plt.show()

# %% [markdown]
# Видно, что разделили выборки удовлетворительно

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера:</b>
#
# Наглядная визуализация выборок👍
#
# </div>

# %% [markdown]
# ## Анализ

# %%
y_train.plot(figsize = (21,6))
decomposed = seasonal_decompose(y_train) 
decomposed.trend.plot()
plt.title('Тренд')
plt.ylabel('Количество заказов')
plt.xlabel('Время')
plt.legend(loc ='upper left')

# %% [markdown]
# В изменении количества заказаов такси наблюдается явный тренд

# %%
y_train['2018-07-21':'2018-07-26'].plot()
decomposed.seasonal['2018-07-21':'2018-07-26'].plot(figsize = (21,6))
plt.title('Сезонность')
plt.ylabel('Количество заказов')
plt.xlabel('Время')
plt.legend(loc ='upper left');

# %% [markdown]
# И сезонность поэтому наиболее оптимальной видется модель SARIMA. Поскольку она учитывает и сезонность и тренд.

# %% [markdown]
# Модель SARIMA
# делал по лекции от Data Mining in Action
# https://www.youtube.com/watch?v=u433nrxdf5k&t=3548s

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера:</b>
#
# Молодец, что изучил дополнительный материал🔥
#
# Да, хорошая лекция.
#
# </div>

# %%
y_train_frame = y_train.to_frame(name='day')

# %%
p_value = adfuller(y_train_frame, regression='ctt')[1]
print('p =', p_value)
# Out:
# p = 1.2916500364438518e-17

# %% [markdown]
# Мы видим , чтот выборка является стационарной судя по критерию.

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера:</b>
#
# Здорово, что проведен тест Дикки-Фуллера для проверки на стационарность ряда 🔥
#
# ***
#
# Расширенный Тест Дики — Фуллера, 4 версии теста:
#
# Без константы и тренда: 'nc' \
# С константой, но без тренда: 'c' \
# С константой и линейным трендом: 'ct' \
# С константой, линейным и квадратичным трендом: 'ctt'
#
# Т.е. можно так:
#
#     ts = taxi['num_orders']
#     st_test = adfuller(ts, regression='ctt')
#
# </div>

# %% [markdown]
# Первым шагом дифференцируем сезонность. поскольку у нас сезонность равняется суткам, берем смещение 24 часа

# %% [markdown]
# <div class="alert alert-warning">
# <b>⚠️ Комментарий ревьюера:</b>
#
# Тут уточнить, ты определил, что ряд стационарный, почему тогда дифференцируешь?
#
# Чтобы сделать ряд стационарным для последующего построения прогноза, используют стабилизацию дисперсии; логарифмирование, дифференцирование ряда.
#
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента:</b> Вопрос у меня этот тоже возник. в начале дифференцировал на размер сезона исходя из лекции на ютубе.
#
# сейчас пересмотрел этот момент на видео. что-то мне показалось. что надо сделать с начала сезонное и хотябы одно на час. но я ошибся</div>

# %%
train_dif_1 = y_train_frame - y_train_frame.shift(24)
train_dif_1.dropna(inplace=True)
decomposed_dif_1 = seasonal_decompose(train_dif_1)
decomposed_dif_1.trend.plot(figsize=(21,6), title='trend')
p_value = adfuller(train_dif_1)[1]
print('p =', p_value)
print('std =', np.std(train_dif_1)[0]);
# Out:
# p = 1.7554242153780222e-27
# std = 30.501797765749245

# %% [markdown]
# Добавим дифференцирование на 1 час, чтобы предсказание делалось исходя из пердыдущего часа а не из текущего

# %%
train_dif_2 = train_dif_1 - train_dif_1.shift(1)
train_dif_2.dropna(inplace=True)
decomposed_dif_2 = seasonal_decompose(train_dif_2)
decomposed_dif_2.trend.plot(figsize=(21,6), title='trend')
p_value = adfuller(train_dif_2)[1]
print('p =', p_value)
print('std =',np.std(train_dif_2)[0])
# Out:
# p = 0.0
# std = 37.29680623799843

# %% [markdown]
# Попробуем сделать второе дифференцирования, для увеличения качества прогноза.

# %% [markdown]
# Дисперсия еще увеличилась, так что остановимся на первом дифференцировании. Соответственно получаем коэффициентьы D=1, d=1.

# %%
plot_acf(y_train_frame)
plt.show()
plot_pacf(y_train_frame)
plt.show()

# %% [markdown]
# Исходя из показателей автокорреляции и частичной автокорреляции выбираем пареметры q = 6 (надо бы взять 14, но считать он будет целую вечность) и р = 2

# %% [markdown]
# Исходя из графика

# %%
plot_acf(y_train_frame, lags=400)
plt.show()
plot_pacf(y_train_frame, lags=200)
plt.show()

# %% [markdown]
#  Исходя из показателей автокорреляции и частичной автокорреляции выбираем пареметры Q=16 и P= 5

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента:</b> сменил гиперпараметры.</div>

# %% [markdown]
# ## Обучение

# %%
y_train
# Out:
# datetime
# 2018-03-02 22:00:00    119
# 2018-03-02 23:00:00     72
# 2018-03-03 00:00:00    163
# 2018-03-03 01:00:00    108
# 2018-03-03 02:00:00     25
#                       ...
# 2018-07-25 23:00:00    138
# 2018-07-26 00:00:00    149
# 2018-07-26 01:00:00     73
# 2018-07-26 02:00:00    197
# 2018-07-26 03:00:00    141
# Freq: H, Name: num_orders, Length: 3486, dtype: int16

# %%
y_train2 = y_train['2018-06-26':]

# %%
y_train2
# Out:
# datetime
# 2018-06-26 00:00:00    104
# 2018-06-26 01:00:00     99
# 2018-06-26 02:00:00     95
# 2018-06-26 03:00:00     93
# 2018-06-26 04:00:00     89
#                       ...
# 2018-07-25 23:00:00    138
# 2018-07-26 00:00:00    149
# 2018-07-26 01:00:00     73
# 2018-07-26 02:00:00    197
# 2018-07-26 03:00:00    141
# Freq: H, Name: num_orders, Length: 724, dtype: int16

# %%
model_result = pd.DataFrame({'Name': [],
                             'RMSE' : [],
                             })

# %% [markdown]
# SARIMA(p,d,q)(P,D,Q)m,
#
# где
# d = 1, D = 1, p = 2, q = 6, Q = 16, P = 5, m = 24

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента:</b> Скажи пожалуйста правильно ли подобраны пареметры? а то качество модели стало ниже.</div>

# %%
model_SARIMA = SARIMAX(y_train2, 
                order = (2, 0, 6), 
                seasonal_order = (5, 0, 8, 24))

model_SARIMA = model_SARIMA.fit()

start = len(y_train2)
end = len(y_train2) + len(y_valid) - 1
  
y_pred = model_SARIMA.predict(start, end)

fh = y_valid.index

print('RMSE = ', np.sqrt(mean_squared_error(y_valid, y_pred)))
plt.figure(figsize = (21,6))
plt.plot(y_valid, color = "black", label = 'Истинные')
plt.plot(y_pred, color = "red", label = 'Предсказанные')
plt.title('Анализ пердсказаний')
plt.ylabel('Количество заказов')
plt.xlabel('Время')
plt.legend(loc ='upper left');

model_result.loc[ len(model_result.index)] = ['model_SARIMA', np.sqrt(mean_squared_error(y_valid, y_pred))]
# Out:
# RMSE =  32.047588003388334

# %%
# model_AutoARIMA = AutoARIMA(sp=24)
# model_AutoARIMA.fit(y_train2)
# y_pred = model_AutoARIMA.predict(fh)

# print('RMSE = ', np.sqrt(mean_squared_error(y_valid, y_pred)))
# plt.figure(figsize = (21,6))
# plt.plot(y_valid, color = "black", label = 'Истинные')
# plt.plot(y_pred, color = "red", label = 'Предсказанные')
# plt.title('Анализ пердсказаний')
# plt.ylabel('Количество заказов')
# plt.xlabel('Время')
# plt.legend(loc ='upper left');
# model_result.loc[ len(model_result.index)] = ['model_AutoARIMA', np.sqrt(mean_squared_error(y_valid, y_pred))]

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента:</b> пришлось убрать
# </div>

# %% [markdown]
# Авто ARIMA показала себя гораздо хуже

# %%
# model_NaiveForecaster = NaiveForecaster(strategy="last", sp=24)

# model_NaiveForecaster.fit(y_train2)
# y_pred = model_NaiveForecaster.predict(fh)

# print('RMSE = ', np.sqrt(mean_squared_error(y_valid, y_pred)))
# plt.figure(figsize = (21,6))
# plt.plot(y_valid, color = "black", label = 'Истинные')
# plt.plot(y_pred, color = "red", label = 'Предсказанные')
# plt.title('Анализ пердсказаний')
# plt.ylabel('Количество заказов')
# plt.xlabel('Время')
# plt.legend(loc ='upper left');
# model_result.loc[ len(model_result.index)] = ['model_NaiveForecaster', np.sqrt(mean_squared_error(y_valid, y_pred))]

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента:</b> пришлось убрать
# </div>

# %%
# model_AutoETS = AutoETS(auto=True, sp=24, n_jobs=-1)

# model_AutoETS.fit(y_train)
# y_pred = model_AutoETS.predict(fh)

# print('RMSE = ', np.sqrt(mean_squared_error(y_valid, y_pred)))
# plt.figure(figsize = (21,6))
# plt.plot(y_valid, color = "black", label = 'Истинные')
# plt.plot(y_pred, color = "red", label = 'Предсказанные')
# plt.title('Анализ пердсказаний')
# plt.ylabel('Количество заказов')
# plt.xlabel('Время')
# plt.legend(loc ='upper left');
# model_result.loc[ len(model_result.index)] = ['model_AutoETS', np.sqrt(mean_squared_error(y_valid, y_pred))]

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента:</b> пришлось убрать к сожалению. А она была очень хороша.
# </div>

# %% [markdown]
# У данной модели очень хороший показатель. И время обучение хорошее

# %%
model_MLPRegressor = MLPRegressor()
model_MLPRegressor.fit(X_train, y_train)
y_pred = model_MLPRegressor.predict(X_valid)
fh = y_valid.index
y_pred = pd.Series(y_pred, index=fh)

plt.figure(figsize = (21,6))
plt.plot(y_valid, color = "black", label = 'Истинные')
plt.plot(y_pred, color = "red", label = 'Предсказанные')
plt.title('Анализ пердсказаний')
plt.ylabel('Количество заказов')
plt.xlabel('Время')
plt.legend(loc ='upper left');

print(np.sqrt(mean_squared_error(y_valid, y_pred)))
model_result.loc[ len(model_result.index)] = ['model_MLPRegressor', np.sqrt(mean_squared_error(y_valid, y_pred))]
# Out:
# 32.50099074747751

# %%
model_CatBoostRegressor = CatBoostRegressor()
model_CatBoostRegressor.fit(X_train, y_train)
y_pred = model_CatBoostRegressor.predict(X_valid)
y_pred = pd.Series(y_pred, index=fh)
plt.figure(figsize = (21,6))
plt.plot(y_valid, color = "black", label = 'Истинные')
plt.plot(y_pred, color = "red", label = 'Предсказанные')
plt.title('Анализ пердсказаний')
plt.ylabel('Количество заказов')
plt.xlabel('Время')
plt.legend(loc ='upper left');

print(np.sqrt(mean_squared_error(y_valid, y_pred)))
model_result.loc[ len(model_result.index)] = ['model_CatBoostRegressor', np.sqrt(mean_squared_error(y_valid, y_pred))]
# Out:
# Learning rate set to 0.049873
# 0:	learn: 34.9400808	total: 225ms	remaining: 3m 44s
# 1:	learn: 34.1919198	total: 227ms	remaining: 1m 53s
# 2:	learn: 33.4980252	total: 230ms	remaining: 1m 16s
# 3:	learn: 32.7639758	total: 233ms	remaining: 57.9s
# 4:	learn: 32.1346591	total: 235ms	remaining: 46.8s
# 5:	learn: 31.4901241	total: 238ms	remaining: 39.4s
# 6:	learn: 30.8758240	total: 240ms	remaining: 34.1s
# 7:	learn: 30.3281999	total: 243ms	remaining: 30.1s
# 8:	learn: 29.8310994	total: 245ms	remaining: 27s
# 9:	learn: 29.3420103	total: 247ms	remaining: 24.5s
# 10:	learn: 28.8810756	total: 250ms	remaining: 22.5s
# 11:	learn: 28.4663451	total: 252ms	remaining: 20.8s
# 12:	learn: 28.0754972	total: 255ms	remaining: 19.3s
# 13:	learn: 27.6652642	total: 257ms	remaining: 18.1s
# 14:	learn: 27.3441016	total: 260ms	remaining: 17s
# 15:	learn: 27.0167726	total: 262ms	remaining: 16.1s
# 16:	learn: 26.7271743	total: 264ms	remaining: 15.3s
# 17:	learn: 26.4287711	total: 267ms	remaining: 14.6s
# ...

# %%
model_LGBMRegressor = lgb.LGBMRegressor(boosting_type='gbdt', learning_rate=0.3, max_depth=9, n_estimators=500)

model_LGBMRegressor.fit(X_train, y_train)
y_pred = model_LGBMRegressor.predict(X_valid)
y_pred = pd.Series(y_pred, index=fh)
plt.figure(figsize = (21,6))
plt.plot(y_valid, color = "black", label = 'Истинные')
plt.plot(y_pred, color = "red", label = 'Предсказанные')
plt.title('Анализ пердсказаний')
plt.ylabel('Количество заказов')
plt.xlabel('Время')
plt.legend(loc ='upper left');

print(np.sqrt(mean_squared_error(y_valid, y_pred)))
model_result.loc[ len(model_result.index)] = ['model_LGBMRegressor', np.sqrt(mean_squared_error(y_valid, y_pred))]
# Out:
# 32.088224286102665

# %%
model_LinearRegression = LinearRegression()
model_LinearRegression.fit(X_train, y_train)
y_pred = model_LinearRegression.predict(X_valid)
y_pred = pd.Series(y_pred, index=fh)
plt.figure(figsize = (21,6))
plt.plot(y_valid, color = "black", label = 'Истинные')
plt.plot(y_pred, color = "red", label = 'Предсказанные')
plt.title('Анализ пердсказаний')
plt.ylabel('Количество заказов')
plt.xlabel('Время')
plt.legend(loc ='upper left');

print(np.sqrt(mean_squared_error(y_valid, y_pred)))
model_result.loc[ len(model_result.index)] = ['model_LinearRegression', np.sqrt(mean_squared_error(y_valid, y_pred))]
# Out:
# 35.485364024080674

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера:</b>
#
# Здорово, что визуализируешь предсказания и реальные значения👍
#
# </div>

# %% [markdown]
# ## Тестирование

# %%
model_result
# Out:
#                       Name       RMSE
# 0             model_SARIMA  32.047588
# 1             model_SARIMA  32.047588
# 2       model_MLPRegressor  32.500991
# 3  model_CatBoostRegressor  31.404143
# 4      model_LGBMRegressor  32.088224
# 5   model_LinearRegression  35.485364

# %% [markdown]
# Как мы видим лучше всего себя показала модель SARIMA с подобранными вручную параметрами. RMSE =  31.0536 Будем тестировать ее

# %%
train, test = train_test_split(data, shuffle=False, test_size=0.1, random_state=12345)
train = train.dropna()

X_train = train.drop('num_orders', axis=1)
y_train = train['num_orders']
X_test = test.drop('num_orders', axis=1)
y_test = test['num_orders']
y_train2 = y_train['2018-06-12':] #это чтобы она не обучалась вечность

# %% [markdown]
# Разбили заново тестовую и обучающую выборку без валидационной.

# %%
model_SARIMA = SARIMAX(y_train2, 
                order = (2, 0, 6), 
                seasonal_order = (5, 0, 8, 24))

model_SARIMA = model_SARIMA.fit()

start = len(y_train2)
end = len(y_train2) + len(y_test) - 1
  
y_pred = model_SARIMA.predict(start, end)

print('model SARIMA. RMSE = ',np.sqrt(mean_squared_error(y_test, y_pred)))
plt.figure(figsize = (21,6))
plt.plot(y_test, color = "black")
plt.plot(y_pred, color = "red")

# %%
model_CatBoostRegressor = CatBoostRegressor()
model_CatBoostRegressor.fit(X_train, y_train)
y_pred = model_CatBoostRegressor.predict(X_test)
y_pred = pd.Series(y_pred, index=fh)
plt.figure(figsize = (21,6))
y_pred.index = y_test.index
plt.plot(y_test, color = "black", label = 'Истинные')
plt.plot(y_pred, color = "red", label = 'Предсказанные')
plt.title('Анализ пердсказаний')
plt.ylabel('Количество заказов')
plt.xlabel('Время')
plt.legend(loc ='upper left');

print(np.sqrt(mean_squared_error(y_test, y_pred)))
model_result.loc[ len(model_result.index)] = ['model_CatBoostRegressor', np.sqrt(mean_squared_error(y_valid, y_pred))]
# Out:
# Learning rate set to 0.05087
# 0:	learn: 37.8585481	total: 4.96ms	remaining: 4.96s
# 1:	learn: 37.0912098	total: 9.34ms	remaining: 4.66s
# 2:	learn: 36.2960404	total: 14.9ms	remaining: 4.94s
# 3:	learn: 35.6198446	total: 19.5ms	remaining: 4.86s
# 4:	learn: 34.9216268	total: 23.6ms	remaining: 4.7s
# 5:	learn: 34.2970815	total: 28.1ms	remaining: 4.65s
# 6:	learn: 33.6996921	total: 31.6ms	remaining: 4.48s
# 7:	learn: 33.1254021	total: 35.9ms	remaining: 4.46s
# 8:	learn: 32.6978829	total: 39.8ms	remaining: 4.38s
# 9:	learn: 32.1228898	total: 42.9ms	remaining: 4.25s
# 10:	learn: 31.7410503	total: 47.1ms	remaining: 4.23s
# 11:	learn: 31.3546748	total: 50.4ms	remaining: 4.15s
# 12:	learn: 30.9244212	total: 53.5ms	remaining: 4.06s
# 13:	learn: 30.5211959	total: 56.7ms	remaining: 3.99s
# 14:	learn: 30.2097916	total: 60ms	remaining: 3.94s
# 15:	learn: 29.8520945	total: 63.2ms	remaining: 3.89s
# 16:	learn: 29.5213334	total: 66.3ms	remaining: 3.83s
# ...

# %% [markdown]
# Обучили модель на новой выборке. Немного приходится подрезать данные, а то обучение будет идти очень долго.
# Как видно мы получили хороший результат и RMSE значительно ниже 48

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера:</b>
#
# Наглядное представление результатов
#
# </div>

# %% [markdown]
# ## Выводы

# %% [markdown]
# В работе мы загрузили данные. Выполнили их ресемплирование по одному часу.
#
# Было показано, что распрежление обладает сезонностью и имеет тренд.
#
# Подобрали параметры  для модели SARIMA.
#
# Испробовали модели: SARIMA, AutoARIMA, NaiveForecaster, AutoETS, MLPRegressor. CatBoostRegressor, LGBMRegressor, LinearRegression
#
# Лучше всего показали себя : SARIMA, AutoETS, CatBoostRegressor.
# Показатели у них были довольно близкие , но лучший результат был у SARIMA
#
# Сделали тестовую выборку размером 10% от исходных данных.
# Обучили и проверили модель.
#
# RMSE =  41.11, что меньше необходимых 48

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера:</b>
#
# Хорошоее резюме проекта👍
#
# </div>

# %% [markdown]
# ***

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Заключительный комментарий ревьюера:</b>
#
# Денис, спасибо за проделанную работу.
#
# Ты основательно изучил тему исследования! Молодец, что рассмотрел новый материал, проработал разные модели для прогнозирования временных рядов. Это, конечно, превышает размах спринта)) У нас были более скромные задачи 😅
#
#
# ***
#
# Проект выполнен хорошо, есть только несколько общих пунктов:
# - До этапа декомпозиции стоит построить график временного ряда (после ресемплирования по часу) + задать скользящее среднее.
# - Стоит добавить общий вывод к этапу (после декомпозиции) - зафиксировать, как менялось количество заказов такси, учитывая графики тренда (за все время) и сезонности.
# - Месяц убрать из признаков, он не требуется из-за того, что в датасете период менее года, тренд будет прослеживаться и без месяца.
#
# ***
#
# Возвращаю тебе работу, чтобы ты смог доделать проект и задать вопросы)
#
# Успехов!
#
# </div>

# %% [markdown]
# ## Чек-лист проверки

# %% [markdown]
# - [x]  Jupyter Notebook открыт
# - [х]  Весь код выполняется без ошибок
# - [х]  Ячейки с кодом расположены в порядке исполнения
# - [х]  Данные загружены и подготовлены
# - [х]  Данные проанализированы
# - [х]  Модель обучена, гиперпараметры подобраны
# - [х]  Качество моделей проверено, выводы сделаны
# - [х]  Значение *RMSE* на тестовой выборке не больше 48
